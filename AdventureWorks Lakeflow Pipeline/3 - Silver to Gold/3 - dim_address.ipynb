-- %%
USE adventureworks.silver;

CREATE OR REPLACE TABLE gold.dim_addres AS
SELECT
  ca.address_id,
  ca.address,
  ca.city,
  ca.state_province,
  ca.country_region,
  ca.postal_code
FROM
  customers_address ca
